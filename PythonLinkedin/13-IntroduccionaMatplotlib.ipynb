# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("../base_datos_2008.csv/base_datos_2008.csv", nrows= 100000)

# %%
data = np.unique(df.Cancelled, return_counts= True)
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %%
plt.pie(x= data[1],
        labels= data[0],
        colors= ["Yellow", "Green"],
        shadow= True,
        startangle= 90,
        radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x2014310cfd0>,
#   <matplotlib.patches.Wedge at 0x2014310d630>],
#  [Text(-0.07891252205766158, -2.1985842749056723, '0'),
#   Text(0.07891259925003043, 2.1985842721350495, '1')])
