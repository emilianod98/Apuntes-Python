# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df = pd.read_csv("../data/aeropuerto.csv", nrows= 1e5)
newdf = df[["AirTime","DepDelay"]].dropna()

# %%
newdf = df[["AirTime","Distance", "TaxiOut", "ArrDelay", "DepDelay"]].dropna()

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(newdf)
kmeans_labels = kmeans.labels_
# Out:
# C:\Users\emida\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([50083,  8064, 18395, 22156], dtype=int64))

# %%
import matplotlib.pyplot as plt
plt.scatter(newdf["AirTime"],newdf["DepDelay"],c = kmeans_labels)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 79.50946731, 116.4478667 ],
#        [ 58.86814825,   5.65975557],
#        [224.74990908,  10.03576191],
#        [128.07685235,   5.12600567]])

# %%
alldf = pd.read_csv("../base_datos_2008.csv/base_datos_2008.csv", nrows= 1e6)[["AirTime","DepDelay"]].dropna()

# %%
kmeans.predict(alldf)[0:50]
# Out:
# array([3, 3, 1, 1, 1, 1, 2, 2, 1, 1, 3, 0, 1, 1, 1, 1, 2, 2, 3, 1, 1, 1,
#        1, 1, 1, 1, 0, 3, 3, 2, 0, 3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 0])
