# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
import numpy as np
import pandas as pd

df = pd.read_csv("../base_datos_2008.csv/base_datos_2008.csv")
df = df.sample(frac=1)
df = df.head(500000)

# %%
df = df.dropna(subset=["ArrDelay"])

# %%
Y = df["ArrDelay"] > 0

# %%
df["Month"] = df["Month"].apply(str)
df["DayofMonth"] = df["DayofMonth"].apply(str)
df["DayOfWeek"] = df["DayOfWeek"].apply(str)
df["TailNum"] = df["TailNum"].apply(str)

X = pd.get_dummies(data=df[["Month","DayofMonth", "DayOfWeek", "Origin", "Dest", "UniqueCarrier", "TailNum"]])

# %%
X.head()
# Out:
#          Month_1  Month_10  Month_11  Month_12  Month_2  Month_3  Month_4  \
# 1154244        0         0         0         0        1        0        0
# 4553646        0         0         0         0        0        0        0
# 2947216        0         0         0         0        0        0        0
# 6268530        0         0         1         0        0        0        0
# 3050580        0         0         0         0        0        0        0
#
#          Month_5  Month_6  Month_7  ...  TailNum_N995DL  TailNum_N996AT  \
# 1154244        0        0        0  ...               0               0
# 4553646        0        0        0  ...               0               0
# 2947216        1        0        0  ...               0               0
# 6268530        0        0        0  ...               0               0
# 3050580        0        1        0  ...               0               0
#
#          TailNum_N996DL  TailNum_N997AT  TailNum_N997DL  TailNum_N998AT  \
# 1154244               0               0               0               0
# 4553646               0               0               0               0
# 2947216               0               0               0               0
# 6268530               0               0               0               0
# 3050580               0               0               0               0
#
#          TailNum_N998DL  TailNum_N999CA  TailNum_N999DN  TailNum_NHZOAL
# 1154244               0               0               0               0
# 4553646               0               0               0               0
# 2947216               0               0               0               0
# 6268530               0               0               0               0
# 3050580               0               0               0               0
#
# [5 rows x 5978 columns]

# %%
clf = BernoulliNB()
#clf = MultinomialNB()
clf.fit(X,Y)
Y_pred = clf.predict(X)

# %%
np.mean(Y == Y_pred)

# %%
1 - np.mean(Y)

# %%
X = df[["AirTime", "Distance", "TaxiIn", "TaxiOut"]] #DepDelay
clf = GaussianNB()
clf.fit(X, Y)
Y_pred = clf.predict(X)

# %%
np.mean(Y == Y_pred)
