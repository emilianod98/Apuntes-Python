# %%
import pandas as pd
df = pd.read_csv("../base_datos_2008.csv/base_datos_2008.csv", nrows= 100000)


df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.tail()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df = df.sample(frac =1)

# %%
df.DepTime
# Out:
# 67927    2007.0
# 32449    1325.0
# 6648     1310.0
# 95292     845.0
# 42143    2049.0
#           ...
# 6680     1619.0
# 12733    1229.0
# 99995    2204.0
# 43807    1911.0
# 10120     755.0
# Name: DepTime, Length: 100000, dtype: float64

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 24, ..., nan, nan, nan],
#        [2008, 1, 13, ..., nan, nan, nan],
#        [2008, 1, 5, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 25, ..., 0.0, 0.0, 129.0],
#        [2008, 1, 16, ..., nan, nan, nan],
#        [2008, 1, 6, ..., nan, nan, nan]], dtype=object)

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 67927  2008      1          24          4   2007.0        1950   2246.0
# 32449  2008      1          13          7   1325.0        1320   1617.0
# 6648   2008      1           5          6   1310.0        1300   1501.0
# 95292  2008      1          29          2    845.0         850   1315.0
# 42143  2008      1          16          3   2049.0        2035   2155.0
# 72950  2008      1          25          5   1140.0        1145   1338.0
# 4983   2008      1           4          5   1531.0        1455   1634.0
# 19399  2008      1           9          3    818.0         820    939.0
# 59545  2008      1          21          1   1055.0         930   1323.0
# 51892  2008      1          18          5   1904.0        1850   2112.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 67927        2240            WN        135  ...    5.0      8.0          0
# ...
